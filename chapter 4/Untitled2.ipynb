# %% [markdown]
# # Linear Models for Classification
# ## 4.1Discriminant Function
# ### 4.1.1 Two classes

# %% [markdown]
# The simplest representation of a linear discriminant function is obtained by tak- ing a linear function of the input vector so that

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714184921.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714184921.jpg)

# %% [markdown]
# Consider two points xA and xB both of which lie on the decision surface. Because y(xA) = y(xB) = 0, we have wT(xA −xB) = 0 and hence the vector w is orthogonal to every vector lying within the decision surface, and so w determines the orientation of the decision surface.

# %% [markdown]
# $$\frac{\mathbf{w}^{\mathrm{T}} \mathbf{x}}{\|\mathbf{w}\|}=-\frac{w_{0}}{\|\mathbf{w}\|}$$

# %% [markdown]
# 此公式适用于线性分类问题，及决策面可以用线性方程表示的情况

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714185847.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714185847.jpg)

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714210411.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714210411.jpg)

# %% [markdown]
# an arbitrary point x and let x⊥ be its orthogonal projection onto the decision surface,
# so that

# %% [markdown]
# $$\mathbf{x}=\mathbf{x}_{\perp}+r \frac{\mathbf{w}}{\|\mathbf{w}\|}$$

# %% [markdown]
# $$r=\frac{y(\mathbf{x})}{\|\mathbf{w}\|}$$

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714211218.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230714211218.jpg)

# %% [markdown]
# ### 4.1.2 Multiple classes

# %% [markdown]
# One-versus-the-rest Consider the use of K−1 classifiers each of which solves a two-class problem of
# separating points in a particular class Ck from points not in that class.

# %% [markdown]
# one-versus-one An alternative is to introduce K(K − 1)/2 binary discriminant functions, one
# for every possible pair of classes.

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20142001.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20142001.png)

# %% [markdown]
# We can avoid these difficulties by considering a single K-class discriminant
# comprising K linear functions of the form

# %% [markdown]
# $$y_{k}(\mathbf{x})=\mathbf{w}_{k}^{\mathrm{T}} \mathbf{x}+w_{k 0}$$

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230718145659.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230718145659.jpg)

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230718145718.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230718145718.jpg)

# %% [markdown]
# and then assigning a point x to class Ck if yk(x) > yj (x) for all j 	≠ k. The decision
# boundary between class Ck and class Cj is therefore given by yk(x) = yj (x) and
# hence corresponds to a (D − 1)-dimensional hyperplane defined by

# %% [markdown]
# $$\left(\mathbf{w}_{k}-\mathbf{w}_{j}\right)^{\mathrm{T}} \mathbf{x}+\left(w_{k 0}-w_{j 0}\right)=0$$

# %% [markdown]
# The decision regions of such a discriminant are always singly connected and
# convex.

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20142347.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20142347.png)

# %% [markdown]
# $$\widehat{\mathbf{x}}=\lambda \mathbf{x}_{\mathrm{A}}+(1-\lambda) \mathbf{x}_{\mathrm{B}}$$

# %% [markdown]
# where 0≤λ≤1. From the linearity of the discriminant functions, it follows that

# %% [markdown]
# $$y_{k}(\widehat{\mathbf{x}})=\lambda y_{k}\left(\mathbf{x}_{\mathrm{A}}\right)+(1-\lambda) y_{k}\left(\mathbf{x}_{\mathrm{B}}\right)$$

# %% [markdown]
# Because both $ \mathrm{x}_{\mathrm{A}}$  and $ \mathrm{x}_{\mathrm{B}} $ lie inside$  \mathcal{R}_{k} $, it follows that $ y_{k}\left(\mathbf{x}_{\mathrm{A}}\right)>y_{j}\left(\mathbf{x}_{\mathrm{A}}\right)$ , and  $y_{k}\left(\mathbf{x}_{\mathrm{B}}\right)>y_{j}\left(\mathbf{x}_{\mathrm{B}}\right)$ , for all  $j \neq k$ , and hence $ y_{k}(\widehat{\mathbf{x}})>y_{j}(\widehat{\mathbf{x}})$ , and so $ \widehat{\mathbf{x}}$  also lies inside $ \mathcal{R}_{k}$ . Thus $ \mathcal{R}_{k} $ is singly connected and convex.

# %% [markdown]
# ### 4.1.3 Least squares for classification

# %% [markdown]
# Each class Ck is described by its own linear model so that

# %% [markdown]
# $$y_{k}(\mathbf{x})=\mathbf{w}_{k}^{\mathrm{T}} \mathbf{x}+w_{k 0}$$

# %% [markdown]
# where k = 1,...,K. We can conveniently group these together using vector notation so that

# %% [markdown]
# $$\mathbf{y}(\mathbf{x})=\widetilde{\mathbf{W}}^{\mathrm{T}} \widetilde{\mathbf{x}}$$

# %% [markdown]
# where  $\widetilde{\mathbf{W}}$  is a matrix whose $ k^{\text {th }} $ column comprises the  D+1 -dimensional vector $ \widetilde{\mathbf{w}}_{k}=\left(w_{k 0} , \mathbf{w}_{k}^{\mathrm{T}}\right)^{\mathrm{T}}$  and  $\widetilde{\mathbf{x}}$  is the corresponding augmented input vector $ \left(1, \mathbf{x}^{\mathrm{T}}\right)^{\mathrm{T}}$  with a dummy input$  x_{0}=1$ . This representation was discussed in detail in Section 3.1. A new input $ \mathbf{x}$  is then assigned to the class for which the output $ y_{k}=\widetilde{\mathbf{w}}_{k}^{\mathrm{T}} \widetilde{\mathbf{x}} $ is largest.
#
# We now determine the parameter matrix $ \widetilde{\mathbf{W}} $ by minimizing a sum-of-squares error function, as we did for regression in Chapter 3. Consider a training data set$  \left\{\mathbf{x}_{n}, \mathbf{t}_{n}\right\} $ where $ n=1, \ldots, N$ , and define a matrix $ \mathbf{T}  whose  n^{\text {th }}$  row is the vector  $\mathbf{t}_{n}^{\mathrm{T}}$ , together with a matrix$  \widetilde{\mathbf{X}}  $whose$  n^{\text {th }} $ row is  $\widetilde{\mathbf{x}}_{n}^{\mathrm{T}}$ . The sum-of-squares error function can then be written as

# %% [markdown]
# $$E_{D}(\widetilde{\mathbf{W}})=\frac{1}{2} \operatorname{Tr}\left\{(\widetilde{\mathbf{X}} \widetilde{\mathbf{W}}-\mathbf{T})^{\mathrm{T}}(\widetilde{\mathbf{X}} \widetilde{\mathbf{W}}-\mathbf{T})\right\}$$ .

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230726221756.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230726221756.jpg)

# %% [markdown]
# Setting the derivative with respect to $ \widetilde{\mathbf{W}} $ to zero, and rearranging, we then obtain the solution for $ \widetilde{\mathbf{W}}$  in the form

# %% [markdown]
# $$\widetilde{\mathbf{W}}=\left(\widetilde{\mathbf{X}}^{\mathrm{T}} \widetilde{\mathbf{X}}\right)^{-1} \widetilde{\mathbf{X}}^{\mathrm{T}} \mathbf{T}=\widetilde{\mathbf{X}}^{\dagger} \mathbf{T}$$

# %% [markdown]
# 相关推导

# %% [markdown]
# 因此，令 $ \frac{\partial E_{D}(\hat{W})}{\partial \hat{W}}=0 $ ，得:
#
# $\hat{W}=\left(\hat{X}^{T} \hat{X}\right)^{-1} \hat{X}^{T} T=\hat{X}^{\dagger} T$
#
#  $\hat{X}^{\dagger}=\left(\hat{X}^{T} \hat{X}\right)^{-1} \hat{X}^{T}$  为矩阵  $\hat{X} $ 得伪逆矩阵。因此，判别函数组为:
#
# $y(x)=\hat{W}^{T} \hat{x}=T^{T}\left(\hat{X}^{\dagger}\right)^{T} \hat{x}$

# %% [markdown]
# Setting the derivative with respect to $ \widetilde{\mathbf{W}}$  to zero, and rearranging, we then obtain the solution for $ \widetilde{\mathbf{W}}$  in the form
#
# $$\widetilde{\mathbf{W}}=\left(\widetilde{\mathbf{X}}^{\mathrm{T}} \tilde{\mathbf{X}}\right)^{-1} \widetilde{\mathbf{X}}^{\mathrm{T}} \mathbf{T}=\widetilde{\mathbf{X}}^{\dagger} \mathbf{T}$$
#
# where  $\widetilde{\mathbf{X}}^{\dagger}$  is the pseudo-inverse of the matrix$  \widetilde{\mathbf{X}} $, as discussed in Section 3.1.1. We then obtain the discriminant function in the form
#
# $$\mathbf{y}(\mathbf{x})=\widetilde{\mathbf{W}}^{\mathrm{T}} \widetilde{\mathbf{x}}=\mathbf{T}^{\mathrm{T}}\left(\widetilde{\mathbf{X}}^{\dagger}\right)^{\mathrm{T}} \tilde{\mathbf{x}}$$ .

# %% [markdown]
# An interesting property of least-squares solutions with multiple target variables
# is that if every target vector in the training set satisfies some linear constraint

# %% [markdown]
# $$\mathbf{a}^{\mathrm{T}} \mathbf{t}_{n}+b=0$$

# %% [markdown]
# for some constants a and b, then the model prediction for any value of x will satisfy the same constraint so that

# %% [markdown]
# $$\mathbf{a}^{\mathrm{T}} \mathbf{y}(\mathbf{x})+b=0$$

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-20%20005212.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-20%20005212.png)

# %% [markdown]
# ### 4.1.4--4.1.6 Fisher’s linear discriminant

# %% [markdown]
# One way to view a linear classification model is in terms of dimensionality
# reduction. Consider first the case of two classes, and suppose we take the D-dimensional input vector x and project it down to one dimension using

# %% [markdown]
# $$y=\mathbf{w}^{\mathrm{T}} \mathbf{x} $$

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20143501.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20143501.png)

# %% [markdown]
# If we place a threshold on  y  and classify $ y \geqslant-w_{0} $ as class $ \mathcal{C}_{1}$ , and otherwise class $ \mathcal{C}_{2}$ , then we obtain our standard linear classifier discussed in the previous section.

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230727000207.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230727000207.jpg)

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-20%20161028.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-20%20161028.png)

# %% [markdown]
# where $ y_{n}=\mathbf{w}^{\mathrm{T}} \mathbf{x}_{n}$ . We can define the total within-class variance for the whole data set to be simply $ s_{1}^{2}+s_{2}^{2}$ . The Fisher criterion is defined to be the ratio of the between-class variance to the within-class variance and is given by
#
# $$J(\mathbf{w})=\frac{\left(m_{2}-m_{1}\right)^{2}}{s_{1}^{2}+s_{2}^{2}}$$

# %% [markdown]
# We can make the dependence on w explicit by using (4.20), (4.23), and (4.24) to rewrite the Fisher criterion in the form

# %% [markdown]
# $$J(\mathbf{w})=\frac{\mathbf{w}^{\mathrm{T}} \mathbf{S}_{\mathrm{B}} \mathbf{w}}{\mathbf{w}^{\mathrm{T}} \mathbf{S}_{\mathrm{W}} \mathbf{w}}$$

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230727001303.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230727001303.jpg)

# %% [markdown]
# where  $\mathbf{S}_{\mathrm{B}}$  is the between-class covariance matrix and is given by
#
# $$\mathbf{S}_{\mathrm{B}}=\left(\mathbf{m}_{2}-\mathbf{m}_{1}\right)\left(\mathbf{m}_{2}-\mathbf{m}_{1}\right)^{\mathrm{T}}$$
#
# and  $\mathbf{S}_{\mathrm{W}} $ is the total within-class covariance matrix, given by
#
# $$\mathbf{S}_{\mathrm{W}}=\sum_{n \in \mathcal{C}_{1}}\left(\mathbf{x}_{n}-\mathbf{m}_{1}\right)\left(\mathbf{x}_{n}-\mathbf{m}_{1}\right)^{\mathrm{T}}+\sum_{n \in \mathcal{C}_{2}}\left(\mathbf{x}_{n}-\mathbf{m}_{2}\right)\left(\mathbf{x}_{n}-\mathbf{m}_{2}\right)^{\mathrm{T}}$$ .
#
# Differentiating (4.26) with respect to $ \mathbf{w} $, we find that $ J(\mathbf{w})$  is maximized when
#
# $$\left(\mathbf{w}^{\mathrm{T}} \mathbf{S}_{\mathrm{B}} \mathbf{w}\right) \mathbf{S}_{\mathrm{W}} \mathbf{w}=\left(\mathbf{w}^{\mathrm{T}} \mathbf{S}_{\mathrm{W}} \mathbf{w}\right) \mathbf{S}_{\mathrm{B}} \mathbf{w} .$$

# %% [markdown]
# From (4.27), we see that $ \mathbf{S}_{\mathrm{B}} \mathbf{w} $ is always in the direction of $ \left(\mathbf{m}_{2}-\mathbf{m}_{1}\right) $. Furthermore, we do not care about the magnitude of $ \mathbf{w} $, only its direction, and so we can drop the scalar factors $ \left(\mathbf{w}^{\mathrm{T}} \mathbf{S}_{\mathrm{B}} \mathbf{w}\right)$ and $ \left(\mathbf{w}^{\mathrm{T}} \mathbf{S}_{\mathrm{W}} \mathbf{w}\right)$ . Multiplying both sides of (4.29) by $ \mathbf{S}_{\mathrm{W}}^{-1} $ we then obtain
#
# $$\mathbf{w} \propto \mathbf{S}_{\mathrm{W}}^{-1}\left(\mathbf{m}_{2}-\mathbf{m}_{1}\right)$$ .
#
# Note that if the within-class covariance is isotropic, so that$  \mathbf{S}_{\mathrm{W}} $ is proportional to the unit matrix, we find that $ \mathbf{w}$  is proportional to the difference of the class means, as discussed above.

# %% [markdown]
# 如果类内协方差矩阵是各向同性（各向同性即指随机向量的协方差矩阵为标量乘以单位矩阵，即每 个方向的方差相同，对角阵是因为相关性在考察两个不同类之间不重要），则 $ S_{W} \propto I $ ，即类内 协方差矩阵正比于单位矩阵，因此其逆矩阵也正比于单位矩阵，则:
#  $w \propto m_{2}-m_{1}$
# 此时，  w  正比于类内均值之差，  w  与类内均值之差的方向相同。

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230727002016.jpg](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20230727002016.jpg)

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20000647.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20000647.png)

# %% [markdown]
# ###  Fisher’s discriminant for multiple classes

# %% [markdown]
# We now consider the generalization of the Fisher discriminant to$  K>2 $ classes, and we shall assume that the dimensionality  D  of the input space is greater than the number  K  of classes. Next, we introduce$  D^{\prime}>1$  linear 'features' $ y_{k}=\mathbf{w}_{k}^{\mathrm{T}} \mathbf{x}$ , where  k=1,$ \ldots, D^{\prime}$ . These feature values can conveniently be grouped together to form a vector  $\mathbf{y} $. Similarly, the weight vectors  $\left\{\mathbf{w}_{k}\right\} $ can be considered to be the columns of a matrix  $\mathbf{W}$ , so that
#
# $$\mathbf{y}=\mathbf{W}^{\mathrm{T}} \mathbf{x}$$
#
# Note that again we are not including any bias parameters in the definition of $ \mathbf{y}$ . The generalization of the within-class covariance matrix to the case of  K  classes follows from (4.28) to give
#
# $$\mathbf{S}_{\mathrm{W}}=\sum_{k=1}^{K} \mathbf{S}_{k}$$
#
# where
#
# $$\begin{aligned}
# \mathbf{S}_{k} & =\sum_{n \in \mathcal{C}_{k}}\left(\mathbf{x}_{n}-\mathbf{m}_{k}\right)\left(\mathbf{x}_{n}-\mathbf{m}_{k}\right)^{\mathrm{T}} \\
# \mathbf{m}_{k} & =\frac{1}{N_{k}} \sum_{n \in \mathcal{C}_{k}} \mathbf{x}_{n}
# \end{aligned}$$
#
# and $ N_{k}$  is the number of patterns in class $ \mathcal{C}_{k}$ . In order to find a generalization of the between-class covariance matrix, we follow Duda and Hart (1973) and consider first the total covariance matrix
#
# $$\mathbf{S}_{\mathrm{T}}=\sum_{n=1}^{N}\left(\mathbf{x}_{n}-\mathbf{m}\right)\left(\mathbf{x}_{n}-\mathbf{m}\right)^{\mathrm{T}}$$

# %% [markdown]
# where$  \mathbf{m}$  is the mean of the total data set
#
# $$\mathbf{m}=\frac{1}{N} \sum_{n=1}^{N} \mathbf{x}_{n}=\frac{1}{N} \sum_{k=1}^{K} N_{k} \mathbf{m}_{k}$$
#
# and $ N=\sum_{k} N_{k} $ is the total number of data points. The total covariance matrix can be decomposed into the sum of the within-class covariance matrix, given by (4.40) and (4.41), plus an additional matrix $ \mathbf{S}_{\mathrm{B}}$ , which we identify as a measure of the between-class covariance
#
# $$\mathbf{S}_{\mathrm{T}}=\mathbf{S}_{\mathrm{W}}+\mathbf{S}_{\mathrm{B}}$$
#
# where
#
# $$\mathbf{S}_{\mathrm{B}}=\sum_{k=1}^{K} N_{k}\left(\mathbf{m}_{k}-\mathbf{m}\right)\left(\mathbf{m}_{k}-\mathbf{m}\right)^{\mathrm{T}}$$ .

# %% [markdown]
# These covariance matrices have been defined in the original $ \mathrm{x}$ -space. We can now define similar matrices in the projected $ D^{\prime} -dimensional y-space$
#
# $$\mathbf{s}_{\mathrm{W}}=\sum_{k=1}^{K} \sum_{n \in \mathcal{C}_{k}}\left(\mathbf{y}_{n}-\boldsymbol{\mu}_{k}\right)\left(\mathbf{y}_{n}-\boldsymbol{\mu}_{k}\right)^{\mathrm{T}}$$
#
# and
#
# $$\mathbf{s}_{\mathrm{B}}=\sum_{k=1}^{K} N_{k}\left(\boldsymbol{\mu}_{k}-\boldsymbol{\mu}\right)\left(\boldsymbol{\mu}_{k}-\boldsymbol{\mu}\right)^{\mathrm{T}}$$
#
# where
#
# $$\boldsymbol{\mu}_{k}=\frac{1}{N_{k}} \sum_{n \in \mathcal{C}_{k}} \mathbf{y}_{n}, \quad \boldsymbol{\mu}=\frac{1}{N} \sum_{k=1}^{K} N_{k} \boldsymbol{\mu}_{k}$$ .
#
# Again we wish to construct a scalar that is large when the between-class covariance is large and when the within-class covariance is small. There are now many possible choices of criterion (Fukunaga, 1990). One example is given by
#
# $$J(\mathbf{W})=\operatorname{Tr}\left\{\mathbf{s}_{\mathrm{W}}^{-1} \mathbf{s}_{\mathrm{B}}\right\}$$
#
# This criterion can then be rewritten as an explicit function of the projection matrix $ \mathbf{W}$  in the form
#
# $$J(\mathbf{w})=\operatorname{Tr}\left\{\left(\mathbf{W} \mathbf{S}_{\mathbf{W}} \mathbf{W}^{\mathrm{T}}\right)^{-1}\left(\mathbf{W} \mathbf{S}_{\mathrm{B}} \mathbf{W}^{\mathrm{T}}\right)\right\}$$

# %% [markdown]
# ### 4.1.7 The perceptron algorithm

# %% [markdown]
# Another example of a linear discriminant model is the perceptron of Rosenblatt (1962), which occupies an important place in the history of pattern recognition algorithms. It corresponds to a two-class model in which the input vector  \mathbf{x}  is first transformed using a fixed nonlinear transformation to give a feature vector  \phi(\mathbf{x}) , and this is then used to construct a generalized linear model of the form
#
# $$y(\mathbf{x})=f\left(\mathbf{w}^{\mathrm{T}} \boldsymbol{\phi}(\mathbf{x})\right)$$

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20003022.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20003022.png)

# %% [markdown]
# We therefore consider an alternative error function known as the perceptron criterion. To derive this, we note that we are seeking a weight vector  $\mathbf{w}$  such that patterns$  \mathbf{x}_{n}$  in class$  \mathcal{C}_{1} $ will have$  \mathbf{w}^{\mathrm{T}} \boldsymbol{\phi}\left(\mathbf{x}_{n}\right)>0 $, whereas patterns $ \mathbf{x}_{n}  $in class  $\mathcal{C}_{2} $ have$  \mathbf{w}^{\mathrm{T}} \boldsymbol{\phi}\left(\mathbf{x}_{n}\right)<0 . Using the  t \in\{-1,+1\}  $target coding scheme it follows that we would like all patterns to satisfy $ \mathbf{w}^{\mathrm{T}} \boldsymbol{\phi}\left(\mathbf{x}_{n}\right) t_{n}>0$ . The perceptron criterion associates zero error with any pattern that is correctly classified, whereas for a misclassified pattern$  \mathbf{x}_{n} $ it tries to minimize the quantity $ -\mathbf{w}^{\mathrm{T}} \boldsymbol{\phi}\left(\mathbf{x}_{n}\right) t_{n}$ . The perceptron criterion is therefore given by
#
# $$E_{\mathrm{P}}(\mathbf{w})=-\sum_{n \in \mathcal{M}} \mathbf{w}^{\mathrm{T}} \boldsymbol{\phi}_{n} t_{n}$$

# %% [markdown]
# We now apply the stochastic gradient descent algorithm to this error function. The change in the weight vector $ \mathbf{w} $ is then given by
#
# $$\mathbf{w}^{(\tau+1)}=\mathbf{w}^{(\tau)}-\eta \nabla E_{\mathrm{P}}(\mathbf{w})=\mathbf{w}^{(\tau)}+\eta \phi_{n} t_{n}$$

# %% [markdown]
# If we consider the effect of a single update in the perceptron learning algorithm, we see that the contribution to the error from a misclassified pattern will be reduced because from (4.55) we have
#
# $$-\mathbf{w}^{(\tau+1) \mathrm{T}} \boldsymbol{\phi}_{n} t_{n}=-\mathbf{w}^{(\tau) \mathrm{T}} \boldsymbol{\phi}_{n} t_{n}-\left(\boldsymbol{\phi}_{n} t_{n}\right)^{\mathrm{T}} \boldsymbol{\phi}_{n} t_{n}<-\mathbf{w}^{(\tau) \mathrm{T}} \boldsymbol{\phi}_{n} t_{n}$$

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20003820.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-27%20003820.png)
